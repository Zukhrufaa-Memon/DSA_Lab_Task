# %%
import requests

# Fetch a web page
r = requests.get("https://www.numl.edu.pk/hyderabad")
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!--> <html lang="en"> <!--<![endif]-->
# <head>
#     <title> Campus </title>
#     <!-- Meta -->
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="description" content="">
#     <meta name="author" content="">
#     <link rel="shortcut icon" href="favicon.ico">
#     <link href='https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700' rel='stylesheet' type='text/css'>
#     <!-- Global CSS -->
#     <link rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/plugins/bootstrap/css/bootstrap.min.css">
#     <!-- Plugins CSS -->
#     <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css">
#     <link rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/plugins/flexslider/flexslider.css">
#     <link rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/plugins/pretty-photo/css/prettyPhoto.css">
#     <!-- Theme CSS -->
#
#
#     <!-- <link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles.css"> -->
#
#
#             			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-dark.css">
#                     			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-medium.css">
#                     			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-medium.css">
#                                 <link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-medium.css">
# 		            			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-medium.css">
#                     			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-medium.css">
#                     			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-medium.css">
#                     			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-light1.css">
#                     			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-medium.css">
#                     			<link id="theme-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/styles-dark.css">
#
#     <link id="common-style" rel="stylesheet" href="https://www.numl.edu.pk/campus/assets/css/commonStyle.css">
#
#
#     <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#       <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
#     <![endif]-->
#
#     <style type="text/css">
# .col-md-4.news-item{border-right: 1px groove;}
# .col-md-4.news-item:nth-child(n+3) {border-right: 0px;}
# </style>
# </head>
#
# <body class="home-page">
#     <div class="wrapper">
# 		<!-- ******HEADER****** -->
# <header class="header">
#     <div class="top-bar">
#         <div class="container">
#
#             <ul class="nav navbar-nav navbar-right">
#                 <!-- <li class=""><a style="color:white; " href="https://numl.edu.pk/NUMLAlumni"> Alumni </a></li> -->
# 								<li class=""><a style="color:white; " href="https://www.numl.edu.pk/hyderabad/campus/gallery"> Gallery </a></li>
#                 <li class=""><a style="color:white; " href="https://www.numl.edu.pk/hyderabad/campus/scholarships">Scholarships</a></li>
#                 <li class=""><a style="color:white; " href="https://www.numl.edu.pk/hyderabad/campus/tenders">Tenders</a></li>
#                 <li class=""><a style="color:white; " href="https://www.numl.edu.pk/hyderabad/campus/jobs">Jobs <span class="sr-only">(current)</span></a></li>
#             </ul>
#
#         </div>
#     </div><!--//to-bar-->
#     <div class="header-main container">
#         <h1 class="logo col-md-6 col-sm-6">
#             <a href="https://www.numl.edu.pk/hyderabad">
#                 <div class="row col-lg-3">
#                     <img id="logo" src="https://www.numl.edu.pk/images/logo/logo.png" alt="NUML-logo" style="width:95px;">
#                 </div>
#                 <div class="row col-lg-9">
#                     <h1 style="margin:0px; color: #072F5F; font-weight: bold;">NUML</h1>
#                     <h4 style="margin:0px; color: #3895D3; padding-top: 5px;">National University of Modern Languages<br/> <b>Hyderabad  Campus </b></h4>
#                 </div>
#             </a>
#         </h1><!--//logo-->
#         <div class="info col-md-6 col-sm-6">
#             <ul class="menu-top navbar-right hidden-xs" id="topButtons">
#                 <li class="btn btn-info" style="background:#16499A;"><a href="https://www.numl.edu.pk"><i class="fa fa-home"></i>Main Site</a></li>
#                 <li class="btn btn-primary" style="background:#0C5C00;"><a href="https://www.numl.edu.pk/admission"><i class="fa fa-link"></i>Admission</a></li>
# 									<li class="btn btn-danger" style="background:#2F8BE4;"><a href="https://lms3.numl.edu.pk/"><i class="fa fa-leanpub" aria-hidden="true"></i>LMS</a></li>
#                 				<li class="btn btn-success" style="background:#CC338B;"><a href="https://onlineadmission.numl.edu.pk/acadmax/"><i class="fa fa-sign-in" aria-hidden="true"></i>Student Portal</a></li>
#                 <li class="btn" style="background:#AF1A34;"><a href="https://news.numl.edu.pk/"><i class="fa fa-newspaper-o"></i>NEWS&nbsp;&nbsp;&nbsp;</a></li>
#                 <!--
#                 <li class="divider"><a href="faq.html">FAQ</a></li>
#                 <li><a href="contact.html">Contact</a></li>
#                 -->
#             </ul><!--//menu-top-->
#             <br />
#             <div class="contact pull-right hide">
#                 <p class="phone"><i class="fa fa-phone"></i>Call us today 0800 123 4567</p>
#                 <p class="email"><i class="fa fa-envelope"></i><a href="#">enquires@website.com</a></p>
#             </div><!--//contact-->
#         </div><!--//info-->
#     </div><!--//header-main-->
# </header><!--//header-->
#
# <style type="text/css">
# #topButtons{
#     margin-top:25px;
# }
# #topButtons li{
#    padding: 10px;
#    padding-left:4px;
#    padding-right: 4px;
#    margin:3px;
#    border-radius:5px;
#    border: none;
# }
#
#
# #topButtons li a{
#     font-size: 13px;
#     color:white;
#     font-weight: bold;
# }
# </style>		<!-- ******NAV****** -->
# <nav class="main-nav" role="navigation">
#     <div class="container">
#         <div class="navbar-header">
#             <button class="navbar-toggle" type="button" data-toggle="collapse" data-target="#navbar-collapse">
#                 <span class="sr-only">Toggle navigation</span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#             </button><!--//nav-toggle-->
#         </div><!--//navbar-header-->
#         <div class="navbar-collapse collapse" id="navbar-collapse">
#             <ul class="nav navbar-nav" id="mainMenu">
#                 <li class="nav-item "><a href="https://www.numl.edu.pk/hyderabad">Home</a></li>
#
#                 <li class="nav-item dropdown  ">
#                     <a class="dropdown-toggle" data-toggle="dropdown" data-hover="dropdown" data-delay="0" data-close-others="false" href="#">About <i class="fa fa-angle-down"></i></a>
#                     <ul class="dropdown-menu">
#                         <!--<li><a href="https://www.numl.edu.pk/hyderabad/campus/chancellor">Chancellor</a></li>-->
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/rector">Rector Message</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/director-general">Director General</a></li>
#                         							<li><a href="https://www.numl.edu.pk/hyderabad/campus/director">Regional Director</a></li>
# 						                        <li><a href="https://www.numl.edu.pk/hyderabad/campus/vision-mission">Vision & Mission</a></li>
#                     </ul>
#                 </li>
#
#
#                 <li class="nav-item dropdown  ">
#                     <a class="dropdown-toggle" data-toggle="dropdown" data-hover="dropdown" data-delay="0" data-close-others="false" href="#">Admissions <i class="fa fa-angle-down"></i></a>
#                     <ul class="dropdown-menu">
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/admission">Admission</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/structure">Fee Structure</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/programs">Eligibility Criteria</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/faqs">FAQs</a></li>
#                     </ul>
#                 </li>
#
#                                     <li class="nav-item dropdown  ">
#                         <a class="dropdown-toggle" data-toggle="dropdown" data-hover="dropdown" data-delay="0" data-close-others="false" href="#">Faculties <i class="fa fa-angle-down"></i></a>
#                         <ul class="dropdown-menu">
#                                                             <li class="dropdown-submenu">
#                                     <a  data-close-others="false" href="https://www.numl.edu.pk/hyderabad/campus/faculties/160">Faculty of Management Sciences&nbsp;&nbsp;<i class="fa fa-angle-right"></i></a>
#                                                                             <ul class="dropdown-menu">
#                                                                                                                                                 <li><a href="https://www.numl.edu.pk/hyderabad/campus/department/347">Department of Commerce and Accounting</a></li>
#                                                                                                                                                                                                 <li><a href="https://www.numl.edu.pk/hyderabad/campus/department/258">Department of Management Sciences</a></li>
#                                                                                                                                                                                                                                 </ul>
#                                                                     </li>
#                                                             <li class="dropdown-submenu">
#                                     <a  data-close-others="false" href="https://www.numl.edu.pk/hyderabad/campus/faculties/162">Faculty of Social Sciences&nbsp;&nbsp;<i class="fa fa-angle-right"></i></a>
#                                                                             <ul class="dropdown-menu">
#                                                                                                                                                                                                                                             <li><a href="https://www.numl.edu.pk/hyderabad/campus/department/290">Department of Media And Communication Studies</a></li>
#                                                                                                                                                                                                                                 </ul>
#                                                                     </li>
#                                                             <li class="dropdown-submenu">
#                                     <a  data-close-others="false" href="https://www.numl.edu.pk/hyderabad/campus/faculties/180">Faculty of Engineering and Computer Sciences&nbsp;&nbsp;<i class="fa fa-angle-right"></i></a>
#                                                                             <ul class="dropdown-menu">
#                                                                                                                                                 <li><a href="https://www.numl.edu.pk/hyderabad/campus/department/331">Department of Computer Science</a></li>
#                                                                                                                                     </ul>
#                                                                     </li>
#                                                             <li class="dropdown-submenu">
#                                     <a  data-close-others="false" href="https://www.numl.edu.pk/hyderabad/campus/faculties/181">Faculty of Arts and Humanities&nbsp;&nbsp;<i class="fa fa-angle-right"></i></a>
#                                                                             <ul class="dropdown-menu">
#                                                                                                                                                 <li><a href="https://www.numl.edu.pk/hyderabad/campus/department/348">Department of English (GS)</a></li>
#                                                                                                                                                                                                 <li><a href="https://www.numl.edu.pk/hyderabad/campus/department/332">Department of English (UGS)</a></li>
#                                                                                                                                     </ul>
#                                                                     </li>
#
#                         </ul>
#                     </li>
#                                 <li class="nav-item "><a href="https://www.numl.edu.pk/hyderabad/campus/programs">Programs</a></li>
#
#                                 <li class="nav-item dropdown  ">
#                     <a class="dropdown-toggle" data-toggle="dropdown" data-hover="dropdown" data-delay="0" data-close-others="false" href="#">Offices <i class="fa fa-angle-down"></i></a>
#                     <ul class="dropdown-menu">
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Rector%20Office">Rector Office</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Director%20General%20Office">Director General Office</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/RSI%20Research%20%26%20Strategic%20Initiatives">RSI Research &amp; Strategic Initiatives</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Registrar%20Office">Registrar Office</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Bureau%20of%20Translation%20and%20Interpretation%20Office">Bureau of Translation and Interpretation Office</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Administration%20Branch">Administration Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/HR%20Branch">HR Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Academics%20Branch">Academics Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Finance%20Branch">Finance Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Examination%20Branch">Examination Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/ICT%20Office">ICT Office</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/QEC">QEC</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/BICON">BICON</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/ITCON">ITCON</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Publication%20Branch">Publication Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/P%26C%20Branch">P&amp;C Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Student%20Affairs%20Branch">Student Affairs Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Sir%20Syed%20Library">Sir Syed Library</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Technical%20Branch">Technical Branch</a></li>
#                                                     <li><a href="https://www.numl.edu.pk/hyderabad/campus/about/Sports%20Branch">Sports Branch</a></li>
#
#                     </ul>
#                 </li>
#
#
#                 <li class="nav-item   "><a href="https://www.numl.edu.pk/hyderabad/campus/downloads">Downloads</a></li>
#
#                 <li class="nav-item   "><a href="https://www.numl.edu.pk/hyderabad/campus/contacts">Contact</a></li>
#
# 				<li class="nav-item   "><a href="https://www.numl.edu.pk/facultyfinder/hyderabad">Faculty Finder</a></li>
#             </ul><!--//nav-->
#         </div><!--//navabr-collapse-->
#     </div><!--//container-->
# </nav><!--//main-nav-->
# 		<!-- ******CONTENT****** -->
#         <div class="content container">
#             	<div id="promo-slider" class="slider flexslider">
#         <ul class="slides">
#
#                                                 <li>
#                         <img src="https://www.numl.edu.pk/attachments/slider/f3dced045c20255.PNG"  alt="" />
#                         <p class="flex-caption">
#                             <span class="main" ></span>
#                             <br />
#                             <span class="secondary clearfix" ></span>
#                         </p>
#                     </li>
#                                     </ul><!--//slides-->
#     </div><!--//flexslider-->
#
#
#     <section class="promo box box-dark">
#         <div class="col-md-4">
#             <h1 class="section-heading">Welcome to Hyderabad  Campus </h1>
#             <p><p><span style="font-family:Arial,Helvetica,sans-serif">The National University of Modern Languages Hyderabad Campus was established in 2007.&nbsp;It is the first federal chartered government university in Hyderabad.</span></p></p>
#         </div>
#
#         <div class="col-md-8" style="padding:0px;">
#             <h1 class="section-heading col-lg-12"> Director  Message</h1>
#
#                 <div class="section-content">
#                     <div class="row">
#                         <div class="col-lg-9">
#
#                             <p><b style="font-size:18px; font-weight:normal;"> Brig Arshad Iqbal, SI (M) Retd </b></p>
#                             <p>
#                                 <p style="text-align:justify"><span style="font-size:11pt"><span style="font-family:Calibri,sans-serif"><span style="font-size:12.0pt"><span style="font-family:&quot;Times New Roman&quot;,serif">It is an extreme honor and privilege for me to lead one...
#                                                                     <a class="read-more" style="color:orange;" href="https://www.numl.edu.pk/hyderabad/campus/director" style="position:unset; bottom:30px; display:inline;">read more<i class="fa fa-chevron-right"></i></a>
#                                                             </p>
#
#                         </div>
#
#                         <div class="col-lg-3" style="padding:0px;">
#
#                                                             <img src="https://www.numl.edu.pk/campus/rd/3c69b8b05712c5d.jpeg" class="img-responsive" alt="Brig Arshad Iqbal, SI (M) Retd" width="100%" height="225">
#                                                     </div>
#                     </div>
#                 </div><!--//section-content-->
#
#         </div>
#
#
#     </section><!--//promo-->
#     <section class="news">
#         <h1 class="section-heading text-highlight"><span class="line"><b>Latest Announcements</b></span></h1>
#         <div class="carousel-controls">
#             <a class="prev" href="#news-carousel" data-slide="prev"><i class="fa fa-caret-left"></i></a>
#             <a class="next" href="#news-carousel" data-slide="next"><i class="fa fa-caret-right"></i></a>
#         </div><!--//carousel-controls-->
#         <div class="section-content clearfix">
#             <div id="news-carousel" class="news-carousel carousel slide">
#                 <div class="carousel-inner">
#                     <div class="item active">
#                                                     <div class="col-lg-12 text-center text-muted">No Active Announcement</div>
#                                         </div><!--//carousel-inner-->
#             </div><!--//news-carousel-->
#         </div><!--//section-content-->
#
#         <div class="col-lg-12 text-right">
#             <a class="read-more" href="https://www.numl.edu.pk/hyderabad/campus/announcements" style="position:unset; bottom:30px;">All Announcements<i class="fa fa-chevron-right"></i></a>
#         </div>
#
#     </section><!--//news-->
#     <div class="row cols-wrapper">
#         <div class="col-md-3">
#             <section class="events">
#                 <h1 class="section-heading text-highlight"><span class="line"><b>Events</b></span></h1>
#                 <div class="section-content" style="overflow:auto; height:250px;">
#                                             <div class="event-item text-muted">
#                             No upcomming Event
#                         </div>
#
#                 </div><!--//section-content-->
#                 <div class="col-lg-12 text-right">
#                     <a class="read-more" href="https://www.numl.edu.pk/hyderabad/campus/events" style="position:unset; bottom:30px;">All events<i class="fa fa-chevron-right"></i></a>
#                 </div>
#             </section><!--//events-->
#         </div><!--//col-md-3-->
#         <div class="col-md-6">
#
#
#
#             <section class="video">
#                 <h1 class="section-heading text-highlight"><span class="line"><b> Campus  Tour</b></span></h1>
#
#                 <div class="section-content">
#                     <div class="row">
#                         <div class="col-lg-12">
#                             <p><p style="text-align:justify">Welcome to the National University of Modern Languages (NUML) Hyderabad campus! We are excited to take you on a virtual tour of our beautiful campus.</p>
#
# <p style="text-align:justify">As you step onto our campus, you will be greeted by lush greenery and a serene atmosphere. Our campus is spread over a vast area and features modern infrastructure that provides an exceptional learning environment for our students.</p>
#
# <p style="text-align:justify">The heart of our campus is the main building, which houses classrooms, computer labs, a library, and administrative offices. Our classrooms are equipped with the latest technology and are designed to facilitate a comfortable and interactive learning experience for our students.</p>
#
# <p style="text-align:justify">Our library is a state-of-the-art facility that houses a vast collection of books, journals, and online resources. It provides a perfect setting for students to study, research, and engage in academic discussions.</p>
#
# <p style="text-align:justify">We have a range of recreational facilities on our campus, including a sports complex, a cafeteria, and a student center. Our sports complex features facilities for indoor and outdoor games, while our cafeteria serves a range of delicious and healthy meals.</p>
#
# <p style="text-align:justify">Our student center is a hub for student activities, where students can engage in a variety of co-curricular and extracurricular activities. We also have a dedicated counseling center that provides support to students in need.</p>
#
# <p style="text-align:justify">Finally, our campus is located in the heart of Hyderabad, making it easily accessible from all parts of the city. We invite you to explore our campus and experience the NUML Hyderabad difference.</p></p>
#                         </div>
#
#                                                     <div class="col-lg-12">
#                                                                     <img src="https://www.numl.edu.pk/campus/274e00ede8fcaef.png" class="img-responsive" alt="Hyderabad" width="100%" height="350">
#
#                             </div>
#                                             </div>
#                 </div><!--//section-content-->
#             </section><!--//video-->
#         </div>
#         <div class="col-md-3">
#             <section class="links">
#                 <h1 class="section-heading text-highlight"><span class="line"><b>Quick Links</b></span></h1>
#                 <div class="section-content">
#                                             <p><a href="https://numl.edu.pk/main/theses" target="_blank"><i class="fa fa-caret-right"></i>Thesis Defence</a></p>
#                                             <p><a href="https://numl.edu.pk/scholarships/all" target="_blank"><i class="fa fa-caret-right"></i>Scholarships</a></p>
#                                             <p><a href="http://www.numl.edu.pk/main/highachiever" target="_blank"><i class="fa fa-caret-right"></i>High Achievers</a></p>
#                                             <p><a href="http://hr.numl.edu.pk/" target="_blank"><i class="fa fa-caret-right"></i>HR System</a></p>
#                                             <p><a href="http://elibrary.numl.edu.pk/" target="_blank"><i class="fa fa-caret-right"></i>E-library</a></p>
#                                             <p><a href="http://ereg.numl.edu.pk/JobPlacement/LoginUser/ManagerLoginForm" target="_blank"><i class="fa fa-caret-right"></i>Placement System</a></p>
#                                             <p><a href="https://www.numl.edu.pk/main/opac" target="_blank"><i class="fa fa-caret-right"></i>OPAC</a></p>
#                                             <p><a href="https://ereg.numl.edu.pk/eportal/" target="_blank"><i class="fa fa-caret-right"></i>E - Registration</a></p>
#                                     </div><!--//section-content-->
#             </section><!--//links-->
#             <section class="links">
#                 <h1 class="section-heading text-highlight"><span class="line"><b>Online Resources</b></span></h1>
#                 <div class="section-content">
#                                                                         <p><a href="https://forms.gle/Xak5UfE1piFs9Df28" target="_blank"><i class="fa fa-caret-right"></i>Psychological Counselling Centre</a></p>
#                                                                                                 <p><a href="https://docs.google.com/forms/d/1jeGDkpD42MU58ZnTW58AjvPgvjxEgcDGbR2Ddt6eHEk/viewform?edit_requested=true" target="_blank"><i class="fa fa-caret-right"></i>B ICON Traning Feedback Form</a></p>
#                                                                                                 <p><a href="https://docs.google.com/forms/d/e/1FAIpQLSffbVoAAWB2EC7hZDtt9cv212PKu2yebsIy4EyD-COUYoP4vg/viewform" target="_blank"><i class="fa fa-caret-right"></i>B ICON Trainers/mentors Form</a></p>
#                                                                                                 <p><a href="http://des.hec.gov.pk/" target="_blank"><i class="fa fa-caret-right"></i>Degree Equivalence System</a></p>
#                                                                                                 <p><a href="https://numl.edu.pk/main/access_publications" target="_blank"><i class="fa fa-caret-right"></i>Access of Publications</a></p>
#                                                                                                 <p><a href="https://eservices.hec.gov.pk/#/auth/login" target="_blank"><i class="fa fa-caret-right"></i>Degree Attestation System</a></p>
#                                                                                                 <p><a href="https://www.numl.edu.pk/attachments/resources/7855a3a1f7dd2cb.pdf" target="_blank"><i class="fa fa-caret-right"></i>Directory of Theses</a></p>
#                                                                                                 <p><a href="https://docs.google.com/forms/d/e/1FAIpQLSfZV7VeqEDEN2ZhnD2EKxDm69rtracW4zDwkWx5zRhOlRid5w/viewform" target="_blank"><i class="fa fa-caret-right"></i>BICON - Idea Registration</a></p>
#                                                             </div><!--//section-content-->
#             </section><!--//resources-->
#         </div><!--//col-md-3-->
#     </div><!--//cols-wrapper-->
#     <section class="awards hide">
#         <div id="awards-carousel" class="awards-carousel carousel slide">
#             <div class="carousel-inner">
#                 <div class="item active">
#                     <ul class="logos">
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <a href="#"><img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award1.jpg"  alt="" /></a>
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <a href="#"><img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award2.jpg"  alt="" /></a>
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <a href="#"><img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award3.jpg"  alt="" /></a>
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <a href="#"><img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award4.jpg"  alt="" /></a>
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <a href="#"><img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award5.jpg"  alt="" /></a>
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <a href="#"><img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award6.jpg"  alt="" /></a>
#                         </li>
#                     </ul><!--//slides-->
#                 </div><!--//item-->
#
#                 <div class="item">
#                     <ul class="logos">
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award7.jpg"  alt="" />
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award6.jpg"  alt="" />
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award5.jpg"  alt="" />
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award4.jpg"  alt="" />
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award3.jpg"  alt="" />
#                         </li>
#                         <li class="col-md-2 col-sm-2 col-xs-4">
#                             <img class="img-responsive" src="https://www.numl.edu.pk/campus/assets/images/awards/award2.jpg"  alt="" />
#                         </li>
#                     </ul><!--//slides-->
#                 </div><!--//item-->
#             </div><!--//carousel-inner-->
#             <a class="left carousel-control" href="#awards-carousel" data-slide="prev">
#                 <i class="fa fa-angle-left"></i>
#             </a>
#             <a class="right carousel-control" href="#awards-carousel" data-slide="next">
#                 <i class="fa fa-angle-right"></i>
#             </a>
#
#         </div>
#     </section>
#         </div><!--//content-->
#     </div><!--//wrapper-->
#
#     <!-- ******FOOTER****** -->
#     <footer class="footer">
#         <!-- ******FOOTER****** -->
# <footer class="footer">
#     <div class="footer-content">
#         <div class="container">
#             <div class="row">
#
#             <div class="footer-col col-md-6 col-sm-8 newsletter">
#                 <div class="footer-col-inner ">
#
#                     <h3>
#                         <a href="https://www.numl.edu.pk" class="m-brand__logo-wrapper">
#                             <img src="https://www.numl.edu.pk/images/logo/logo.png" alt="NUML-logo" style="width:95px;">
#                         </a>
#                     </h3>
#                     <p><i class="fa fa-institute"></i>National University of Modern Languages</p>
#                     <p><i class="fa fa-map-marker"></i>H-9 Islamabad ,Pakistan<p>
#                     <p><i class="fa fa-phone"></i><a href="tel:92-51-9265100" target="_top">+92-51-9265100</p>
#                     <p>
#                         <a href="mailto:info@numl.edu.pk" target="_top"><i class="fa fa-envelope"></i>info@numl.edu.pk</a>
#                     </p>
#
#                 </div><!--//footer-col-inner-->
#             </div><!--//foooter-col-->
#
#             <div class="footer-col col-md-3 col-sm-4 about">
#                 <div class="footer-col-inner">
#                     <h3>About</h3>
#                     <ul>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/vision-mission"><i class="fa fa-caret-right"></i>About</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/admission"><i class="fa fa-caret-right"></i>Admissions</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/programs"><i class="fa fa-caret-right"></i>Programs</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/contacts"><i class="fa fa-caret-right"></i>Contact</a></li>
#                     </ul>
#                 </div><!--//footer-col-inner-->
#             </div><!--//foooter-col-->
#
#
#
#             <div class="footer-col col-md-3 col-sm-12 contact">
#                 <div class="footer-col-inner">
#                     <h3>Links</h3>
#                     <ul>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/jobs"><i class="fa fa-caret-right"></i>Jobs</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/tenders"><i class="fa fa-caret-right"></i>Tenders</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/scholarships"><i class="fa fa-caret-right"></i>Scholarships</a></li>
#                         <li><a href="https://www.numl.edu.pk/hyderabad/campus/gallery"><i class="fa fa-caret-right"></i>Gallery</a></li>
#                     </ul>
#                 </div><!--//footer-col-inner-->
#             </div><!--//foooter-col-->
#             </div>
#         </div>
#     </div><!--//footer-content-->
#     <div class="bottom-bar">
#         <div class="container">
#             <div class="row">
#                 <small class="copyright col-md-6 col-sm-12 col-xs-12">2023 © NUML All Rights Reserved developed by <a href="https://www.numl.edu.pk/offices/ICT">ICT Department</a></small>
#                 <ul class="social pull-right col-md-6 col-sm-12 col-xs-12">
#                     <li><a href="https://www.facebook.com/NUMLOFFICIALPAGE/" ><i class="fa fa-facebook"></i></a></li>
#                     <li><a href="https://twitter.com/numl_official" ><i class="fa fa-twitter"></i></a></li>
#                     <li><a href="https://www.youtube.com/channel/UCY_fvvBIFB_2-0-o5a6lAfg/featured" ><i class="fa fa-youtube"></i></a></li>
#                     <li><a href="https://www.linkedin.com/company/numl-official" ><i class="fa fa-linkedin"></i></a></li>
#                     <li class="row-end"><a href="https://www.instagram.com/numlofficial/" ><i class="fa fa-instagram "></i></a></li>
#                 </ul><!--//social-->
#             </div><!--//row-->
#         </div><!--//container-->
#     </div><!--//bottom-bar-->
# </footer><!--//footer-->
#
#
# <!-- Modal -->
#     </footer><!--//footer-->
#
#
#
#
#
# 	<script src="https://code.jquery.com/jquery-2.2.4.min.js" integrity="sha256-BbhdlvQf/xTY9gja0Dq3HiwQF8LaCRTXxZKRutelT44=" crossorigin="anonymous"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/plugins/bootstrap/js/bootstrap.min.js"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/plugins/bootstrap-hover-dropdown.min.js"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/plugins/back-to-top.js"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/plugins/jquery-placeholder/jquery.placeholder.js"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/plugins/pretty-photo/js/jquery.prettyPhoto.js"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/plugins/flexslider/jquery.flexslider-min.js"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/plugins/jflickrfeed/jflickrfeed.min.js"></script>
#     <script type="text/javascript" src="https://www.numl.edu.pk/campus/assets/js/main.js"></script>
#
# 	<script type="text/javascript">
#     $(document).ready(function(){
#         $('#mainMenu li:first-child').addClass('active');
#     });
# </script>
#
#
# <script type="text/javascript">
#
#     $(document).ready(function(){
#
#             })
#
# </script>
#
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=UA-136159115-1"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'UA-136159115-1');
#     </script>
#
#
#
#
#
# </body>
# </html>

# %%
import re

# Remove HTML tags using RegularExpression
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
#
#
#
#
#      Campus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .col-md-4.news-item{border-right: 1px groove;}
# .col-md-4.news-item:nth-child(n+3) {border-right: 0px;}
#
#
#
#
#
#
#
#
#
#
#
#                  Alumni  -->
# 								 Gallery
#                 Scholarships
#                 Tenders
#                 Jobs (current)
#
#
#
#
#
#
#
#
#
#
#
#                     NUML
#                     National University of Modern Languages Hyderabad  Campus
#
#
#
#
#
#                 Main Site
#                 Admission
# 									LMS
#                 				Student Portal
#                 NEWS&nbsp;&nbsp;&nbsp;
#                 <!--
#                 FAQ
#                 Contact
#                 -->
#
#
#
#                 Call us today 0800 123 4567
#                 enquires@website.com
#
#
#
#
#
#
# #topButtons{
#     margin-top:25px;
# }
# #topButtons li{
#    padding: 10px;
#    padding-left:4px;
#    padding-right: 4px;
#    margin:3px;
#    border-radius:5px;
#    border: none;
# }
#
#
# #topButtons li a{
#     font-size: 13px;
#     color:white;
#     font-weight: bold;
# }
#
#
#
#
#
#                 Toggle navigation
#
#
#
#
#
#
#
#                 Home
#
#
#                     About
#
#                         Chancellor-->
#                         Rector Message
#                         Director General
#                         							Regional Director
# 						                        Vision & Mission
#
#
#
#
#
#                     Admissions
#
#                         Admission
#                         Fee Structure
#                         Eligibility Criteria
#                         FAQs
#
#
#
#
#                         Faculties
#
#
#                                     Faculty of Management Sciences&nbsp;&nbsp;
#
#                                                                                                                                                 Department of Commerce and Accounting
#                                                                                                                                                                                                 Department of Management Sciences
#
#
#
#                                     Faculty of Social Sciences&nbsp;&nbsp;
#
#                                                                                                                                                                                                                                             Department of Media And Communication Studies
#
#
#
#                                     Faculty of Engineering and Computer Sciences&nbsp;&nbsp;
#
#                                                                                                                                                 Department of Computer Science
#
#
#
#                                     Faculty of Arts and Humanities&nbsp;&nbsp;
#
#                                                                                                                                                 Department of English (GS)
#                                                                                                                                                                                                 Department of English (UGS)
#
#
#
#
#
#                                 Programs
#
#
#                     Offices
#
#                                                     Rector Office
#                                                     Director General Office
#                                                     RSI Research &amp; Strategic Initiatives
#                                                     Registrar Office
#                                                     Bureau of Translation and Interpretation Office
#                                                     Administration Branch
#                                                     HR Branch
#                                                     Academics Branch
#                                                     Finance Branch
#                                                     Examination Branch
#                                                     ICT Office
#                                                     QEC
#                                                     BICON
#                                                     ITCON
#                                                     Publication Branch
#                                                     P&amp;C Branch
#                                                     Student Affairs Branch
#                                                     Sir Syed Library
#                                                     Technical Branch
#                                                     Sports Branch
#
#
#
#
#
#                 Downloads
#
#                 Contact
#
# 				Faculty Finder
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Welcome to Hyderabad  Campus
#             The National University of Modern Languages Hyderabad Campus was established in 2007.&nbsp;It is the first federal chartered government university in Hyderabad.
#
#
#
#              Director  Message
#
#
#
#
#
#                              Brig Arshad Iqbal, SI (M) Retd
#
#                                 It is an extreme honor and privilege for me to lead one...
#                                                                     read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Latest Announcements
#
#
#
#
#
#
#
#
#                                                     No Active Announcement
#
#
#
#
#
#             All Announcements
#
#
#
#
#
#
#                 Events
#
#
#                             No upcomming Event
#
#
#
#
#                     All events
#
#
#
#
#
#
#
#
#                  Campus  Tour
#
#
#
#
#                             Welcome to the National University of Modern Languages (NUML) Hyderabad campus! We are excited to take you on a virtual tour of our beautiful campus.
#
# As you step onto our campus, you will be greeted by lush greenery and a serene atmosphere. Our campus is spread over a vast area and features modern infrastructure that provides an exceptional learning environment for our students.
#
# The heart of our campus is the main building, which houses classrooms, computer labs, a library, and administrative offices. Our classrooms are equipped with the latest technology and are designed to facilitate a comfortable and interactive learning experience for our students.
#
# Our library is a state-of-the-art facility that houses a vast collection of books, journals, and online resources. It provides a perfect setting for students to study, research, and engage in academic discussions.
#
# We have a range of recreational facilities on our campus, including a sports complex, a cafeteria, and a student center. Our sports complex features facilities for indoor and outdoor games, while our cafeteria serves a range of delicious and healthy meals.
#
# Our student center is a hub for student activities, where students can engage in a variety of co-curricular and extracurricular activities. We also have a dedicated counseling center that provides support to students in need.
#
# Finally, our campus is located in the heart of Hyderabad, making it easily accessible from all parts of the city. We invite you to explore our campus and experience the NUML Hyderabad difference.
#
#
#
#
#
#
#
#
#
#
#
#
#                 Quick Links
#
#                                             Thesis Defence
#                                             Scholarships
#                                             High Achievers
#                                             HR System
#                                             E-library
#                                             Placement System
#                                             OPAC
#                                             E - Registration
#
#
#
#                 Online Resources
#
#                                                                         Psychological Counselling Centre
#                                                                                                 B ICON Traning Feedback Form
#                                                                                                 B ICON Trainers/mentors Form
#                                                                                                 Degree Equivalence System
#                                                                                                 Access of Publications
#                                                                                                 Degree Attestation System
#                                                                                                 Directory of Theses
#                                                                                                 BICON - Idea Registration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     National University of Modern Languages
#                     H-9 Islamabad ,Pakistan
#                     +92-51-9265100
#
#                         info@numl.edu.pk
#
#
#
#
#
#
#
#                     About
#
#                         About
#                         Admissions
#                         Programs
#                         Contact
#
#
#
#
#
#
#
#
#                     Links
#
#                         Jobs
#                         Tenders
#                         Scholarships
#                         Gallery
#
#
#
#
#
#
#
#
#
#                 2023 © NUML All Rights Reserved developed by ICT Department
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     $(document).ready(function(){
#         $('#mainMenu li:first-child').addClass('active');
#     });
#
#
#
#
#
#     $(document).ready(function(){
#
#             })
#
#
#
#
#
#
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'UA-136159115-1');

# %%
from bs4 import BeautifulSoup

# %%
# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#      Campus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .col-md-4.news-item{border-right: 1px groove;}
# .col-md-4.news-item:nth-child(n+3) {border-right: 0px;}
#
#
#
#
#
#
#
#
#
#
#
#
# 								 Gallery
#                 Scholarships
#                 Tenders
#                 Jobs (current)
#
#
#
#
#
#
#
#
#
#
#
#                     NUML
#                     National University of Modern Languages Hyderabad  Campus
#
#
#
#
#
#                 Main Site
#                 Admission
# 									LMS
#                 				Student Portal
#                 NEWS
#
#
#
#
#                 Call us today 0800 123 4567
#                 enquires@website.com
#
#
#
#
#
#
# #topButtons{
#     margin-top:25px;
# }
# #topButtons li{
#    padding: 10px;
#    padding-left:4px;
#    padding-right: 4px;
#    margin:3px;
#    border-radius:5px;
#    border: none;
# }
#
#
# #topButtons li a{
#     font-size: 13px;
#     color:white;
#     font-weight: bold;
# }
#
#
#
#
#
#                 Toggle navigation
#
#
#
#
#
#
#
#                 Home
#
#
#                     About
#
#
#                         Rector Message
#                         Director General
#                         							Regional Director
# 						                        Vision & Mission
#
#
#
#
#
#                     Admissions
#
#                         Admission
#                         Fee Structure
#                         Eligibility Criteria
#                         FAQs
#
#
#
#
#                         Faculties
#
#
#                                     Faculty of Management Sciences
#
#                                                                                                                                                 Department of Commerce and Accounting
#                                                                                                                                                                                                 Department of Management Sciences
#
#
#
#                                     Faculty of Social Sciences
#
#                                                                                                                                                                                                                                             Department of Media And Communication Studies
#
#
#
#                                     Faculty of Engineering and Computer Sciences
#
#                                                                                                                                                 Department of Computer Science
#
#
#
#                                     Faculty of Arts and Humanities
#
#                                                                                                                                                 Department of English (GS)
#                                                                                                                                                                                                 Department of English (UGS)
#
#
#
#
#
#                                 Programs
#
#
#                     Offices
#
#                                                     Rector Office
#                                                     Director General Office
#                                                     RSI Research & Strategic Initiatives
#                                                     Registrar Office
#                                                     Bureau of Translation and Interpretation Office
#                                                     Administration Branch
#                                                     HR Branch
#                                                     Academics Branch
#                                                     Finance Branch
#                                                     Examination Branch
#                                                     ICT Office
#                                                     QEC
#                                                     BICON
#                                                     ITCON
#                                                     Publication Branch
#                                                     P&C Branch
#                                                     Student Affairs Branch
#                                                     Sir Syed Library
#                                                     Technical Branch
#                                                     Sports Branch
#
#
#
#
#
#                 Downloads
#
#                 Contact
#
# 				Faculty Finder
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Welcome to Hyderabad  Campus
#             The National University of Modern Languages Hyderabad Campus was established in 2007. It is the first federal chartered government university in Hyderabad.
#
#
#
#              Director  Message
#
#
#
#
#
#                              Brig Arshad Iqbal, SI (M) Retd
#
#                                 It is an extreme honor and privilege for me to lead one...
#                                                                     read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Latest Announcements
#
#
#
#
#
#
#
#
#                                                     No Active Announcement
#
#
#
#
#
#             All Announcements
#
#
#
#
#
#
#                 Events
#
#
#                             No upcomming Event
#
#
#
#
#                     All events
#
#
#
#
#
#
#
#
#                  Campus  Tour
#
#
#
#
#                             Welcome to the National University of Modern Languages (NUML) Hyderabad campus! We are excited to take you on a virtual tour of our beautiful campus.
#
# As you step onto our campus, you will be greeted by lush greenery and a serene atmosphere. Our campus is spread over a vast area and features modern infrastructure that provides an exceptional learning environment for our students.
#
# The heart of our campus is the main building, which houses classrooms, computer labs, a library, and administrative offices. Our classrooms are equipped with the latest technology and are designed to facilitate a comfortable and interactive learning experience for our students.
#
# Our library is a state-of-the-art facility that houses a vast collection of books, journals, and online resources. It provides a perfect setting for students to study, research, and engage in academic discussions.
#
# We have a range of recreational facilities on our campus, including a sports complex, a cafeteria, and a student center. Our sports complex features facilities for indoor and outdoor games, while our cafeteria serves a range of delicious and healthy meals.
#
# Our student center is a hub for student activities, where students can engage in a variety of co-curricular and extracurricular activities. We also have a dedicated counseling center that provides support to students in need.
#
# Finally, our campus is located in the heart of Hyderabad, making it easily accessible from all parts of the city. We invite you to explore our campus and experience the NUML Hyderabad difference.
#
#
#
#
#
#
#
#
#
#
#
#
#                 Quick Links
#
#                                             Thesis Defence
#                                             Scholarships
#                                             High Achievers
#                                             HR System
#                                             E-library
#                                             Placement System
#                                             OPAC
#                                             E - Registration
#
#
#
#                 Online Resources
#
#                                                                         Psychological Counselling Centre
#                                                                                                 B ICON Traning Feedback Form
#                                                                                                 B ICON Trainers/mentors Form
#                                                                                                 Degree Equivalence System
#                                                                                                 Access of Publications
#                                                                                                 Degree Attestation System
#                                                                                                 Directory of Theses
#                                                                                                 BICON - Idea Registration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     National University of Modern Languages
#                     H-9 Islamabad ,Pakistan
#                     +92-51-9265100
#
#                         info@numl.edu.pk
#
#
#
#
#
#
#
#                     About
#
#                         About
#                         Admissions
#                         Programs
#                         Contact
#
#
#
#
#
#
#
#
#                     Links
#
#                         Jobs
#                         Tenders
#                         Scholarships
#                         Gallery
#
#
#
#
#
#
#
#
#
#                 2023 © NUML All Rights Reserved developed by ICT Department
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     $(document).ready(function(){
#         $('#mainMenu li:first-child').addClass('active');
#     });
#
#
#
#
#
#     $(document).ready(function(){
#
#             })
#
#
#
#
#
#
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'UA-136159115-1');

# %%
#mw-content-container
# Find all articles
summaries = soup.find_all("div", class_="header-main container")
summaries[0];

# %% [markdown]
# Strip Text

# %%
text=summaries[0].get_text().strip()
text
# Out:
# 'NUML\n                    National University of Modern Languages Hyderabad  Campus \n                \n            \n                   \n        \n            \n                Main Site\n                Admission\n\t\t\t\t\t\t\t\t\tLMS\n                \t\t\t\tStudent Portal\n                NEWS\xa0\xa0\xa0\n                \n            \n            \n            \n                Call us today 0800 123 4567 \n                enquires@website.com'

# %% [markdown]
# Make it LowerCase

# %%
# Convert to lowercase
text = text.lower()
print(text)
# Out:
# numl
#                     national university of modern languages hyderabad  campus
#
#
#
#
#
#                 main site
#                 admission
# 									lms
#                 				student portal
#                 news
#
#
#
#
#                 call us today 0800 123 4567
#                 enquires@website.com

# %% [markdown]
# Remove Punctuations

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text)
print(text)
# Out:
# numl                     national university of modern languages hyderabad  campus                                                                                          main site                 admission          lms                     student portal                 news                                                                            call us today 0800 123 4567                  enquires website com

# %% [markdown]
# Split Text

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['numl', 'national', 'university', 'of', 'modern', 'languages', 'hyderabad', 'campus', 'main', 'site', 'admission', 'lms', 'student', 'portal', 'news', 'call', 'us', 'today', '0800', '123', '4567', 'enquires', 'website', 'com']

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
# Reset text
#text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['numl', 'national', 'university', 'of', 'modern', 'languages', 'hyderabad', 'campus', 'main', 'site', 'admission', 'lms', 'student', 'portal', 'news', 'call', 'us', 'today', '0800', '123', '4567', 'enquires', 'website', 'com']

# %% [markdown]
# Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['numl', 'nation', 'univers', 'of', 'modern', 'languag', 'hyderabad', 'campu', 'main', 'site', 'admiss', 'lm', 'student', 'portal', 'news', 'call', 'us', 'today', '0800', '123', '4567', 'enquir', 'websit', 'com']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')


# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['numl', 'national', 'university', 'of', 'modern', 'language', 'hyderabad', 'campus', 'main', 'site', 'admission', 'lm', 'student', 'portal', 'news', 'call', 'u', 'today', '0800', '123', '4567', 'enquires', 'website', 'com']
